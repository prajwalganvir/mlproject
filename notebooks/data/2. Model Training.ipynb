# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("gemstone.csv")

# %%
data.drop(labels=["id"],axis=1,inplace=True)

# %%
data
# Out:
#         carat        cut color clarity  depth  table     x     y     z  price
# 0        1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1        2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2        0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3        0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4        1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453
# ...       ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 193568   0.31      Ideal     D    VVS2   61.1   56.0  4.35  4.39  2.67   1130
# 193569   0.70    Premium     G    VVS2   60.3   58.0  5.75  5.77  3.47   2874
# 193570   0.73  Very Good     F     SI1   63.1   57.0  5.72  5.75  3.62   3036
# 193571   0.34  Very Good     D     SI1   62.9   55.0  4.45  4.49  2.81    681
# 193572   0.71       Good     E     SI2   60.8   64.0  5.73  5.71  3.48   2258
#
# [193573 rows x 10 columns]

# %%
X=data.drop(labels=["price"],axis=1)

# %%
y=data[["price"]]

# %%
X
# Out:
#         carat        cut color clarity  depth  table     x     y     z
# 0        1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55
# 1        2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05
# 2        0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50
# 3        0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71
# 4        1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77
# ...       ...        ...   ...     ...    ...    ...   ...   ...   ...
# 193568   0.31      Ideal     D    VVS2   61.1   56.0  4.35  4.39  2.67
# 193569   0.70    Premium     G    VVS2   60.3   58.0  5.75  5.77  3.47
# 193570   0.73  Very Good     F     SI1   63.1   57.0  5.72  5.75  3.62
# 193571   0.34  Very Good     D     SI1   62.9   55.0  4.45  4.49  2.81
# 193572   0.71       Good     E     SI2   60.8   64.0  5.73  5.71  3.48
#
# [193573 rows x 9 columns]

# %%
y
# Out:
#         price
# 0       13619
# 1       13387
# 2        2772
# 3         666
# 4       14453
# ...       ...
# 193568   1130
# 193569   2874
# 193570   3036
# 193571    681
# 193572   2258
#
# [193573 rows x 1 columns]

# %%
categorical_cols=X.select_dtypes(include='object').columns

# %%
numerical_cols=X.select_dtypes(exclude='object').columns

# %%
numerical_cols
# Out:
# Index(['carat', 'depth', 'table', 'x', 'y', 'z'], dtype='object')

# %%
X.select_dtypes(include='object')
# Out:
#               cut color clarity
# 0         Premium     F     VS2
# 1       Very Good     J     SI2
# 2           Ideal     G     VS1
# 3           Ideal     G     VS1
# 4         Premium     G     VS2
# ...           ...   ...     ...
# 193568      Ideal     D    VVS2
# 193569    Premium     G    VVS2
# 193570  Very Good     F     SI1
# 193571  Very Good     D     SI1
# 193572       Good     E     SI2
#
# [193573 rows x 3 columns]

# %%
# Define the custom ranking for each ordinal variable
cut_categories = ['Fair', 'Good', 'Very Good','Premium','Ideal']
color_categories = ['D', 'E', 'F', 'G', 'H', 'I', 'J']
clarity_categories = ['I1','SI2','SI1','VS2','VS1','VVS2','VVS1','IF']

# %%
from sklearn.impute import SimpleImputer ## HAndling Missing Values
from sklearn.preprocessing import StandardScaler # HAndling Feature Scaling
from sklearn.preprocessing import OrdinalEncoder # Ordinal Encoding
## pipelines
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
num_pipeline=Pipeline(
    
    
    steps=[
        
        ('imputer',SimpleImputer()),
        ('scaler', StandardScaler())
    ]
    
    
)

# %%
cat_pipeline=Pipeline(
    
    steps=[
        ('imputer',SimpleImputer(strategy='most_frequent')),
        ('ordinalencoder',OrdinalEncoder(categories=[cut_categories,color_categories,clarity_categories]))
    ]
    
)

# %%
preprocessor=ColumnTransformer(
    [
        
        ('num_pipeline',num_pipeline,numerical_cols),
        ('cat_pipeline',cat_pipeline,categorical_cols)
    ]
)

# %%
# Out:
# Error: Estimator imputer does not provide get_feature_names_out. Did you mean to call pipeline[:-1].get_feature_names_out()?
# Some transformers do not support 'get_feature_names_out'.

# %%
## Train test split

from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=30)

# %%
preprocessor.fit_transform(X_train)
# Out:
# array([[-0.97543926, -0.84960654, -0.12153081, ...,  4.        ,
#          5.        ,  5.        ],
#        [ 0.2351953 ,  1.83363716, -0.12153081, ...,  1.        ,
#          1.        ,  2.        ],
#        [ 0.49461699,  0.81585507,  0.39980029, ...,  3.        ,
#          3.        ,  4.        ],
#        ...,
#        [ 0.45138004,  1.55606023, -0.6428619 , ...,  1.        ,
#          3.        ,  2.        ],
#        [ 0.66756478, -1.77486298,  1.44246248, ...,  4.        ,
#          3.        ,  4.        ],
#        [ 0.25681377,  0.81585507, -0.12153081, ...,  4.        ,
#          3.        ,  2.        ]])

# %%
preprocessor.transform(X_test)
# Out:
# array([[-0.56468825, -0.94213218, -0.6428619 , ...,  3.        ,
#          1.        ,  3.        ],
#        [-0.17555571,  1.00090636, -0.12153081, ...,  2.        ,
#          4.        ,  2.        ],
#        [-1.06191316,  0.2607012 , -0.12153081, ...,  4.        ,
#          4.        ,  7.        ],
#        ...,
#        [-0.19717419, -3.34779894,  1.44246248, ...,  3.        ,
#          6.        ,  3.        ],
#        [-0.82410994, -0.20192702, -0.12153081, ...,  4.        ,
#          3.        ,  2.        ],
#        [ 2.61322747, -0.75708089,  1.44246248, ...,  3.        ,
#          6.        ,  3.        ]])

# %%
X_test
# Out:
#         carat        cut color clarity  depth  table     x     y     z
# 70432    0.53    Premium     E     VS2   60.8   56.0  5.24  5.21  3.19
# 64839    0.71  Very Good     H     SI1   62.9   57.0  5.67  5.69  3.56
# 185316   0.30      Ideal     H      IF   62.1   57.0  4.27  4.29  2.66
# 84658    1.24    Premium     G     VS2   61.6   61.0  6.88  6.82  4.21
# 31953    0.36    Premium     E     VS1   60.4   58.0  4.60  4.63  2.80
# ...       ...        ...   ...     ...    ...    ...   ...   ...   ...
# 192694   1.26  Very Good     H     VS2   63.1   56.0  6.83  6.87  4.33
# 133935   0.33      Ideal     F    VVS1   62.1   55.0  4.45  4.48  2.77
# 44763    0.70    Premium     J     VS2   58.2   60.0  5.83  5.80  3.38
# 29856    0.41      Ideal     G     SI1   61.6   57.0  4.77  4.75  2.93
# 62426    2.00    Premium     J     VS2   61.0   60.0  8.09  7.97  4.92
#
# [58072 rows x 9 columns]

# %%
X_train=pd.DataFrame(preprocessor.fit_transform(X_train),columns=preprocessor.get_feature_names_out)
X_test=pd.DataFrame(preprocessor.transform(X_test),columns=preprocessor.get_feature_names_out)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
# ----> 1 X_train=pd.DataFrame(preprocessor.fit_transform(X_train),columns=preprocessor.get_feature_names_out)
#       2 X_test=pd.DataFrame(preprocessor.transform(X_test),columns=preprocessor.get_feature_names_out)
#
# File c:\Users\ASUS\anaconda3\lib\site-packages\pandas\core\frame.py:694, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     684         mgr = dict_to_mgr(
#     685             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     686             # attribute "name"
#    (...)
#     691             typ=manager,
#     692         )
#     693     else:
# --> 694         mgr = ndarray_to_mgr(
#     695             data,
#     696             index,
#     697             columns,
#     698             dtype=dtype,
#     699             copy=copy,
#     700             typ=manager,
#     701         )
#     703 # For data is list-like, or Iterable (will consume into list)
#     704 elif is_list_like(data):
#
# File c:\Users\ASUS\anaconda3\lib\site-packages\pandas\core\internals\construction.py:347, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     344     values = values.reshape(shape)
#     346 # _prep_ndarray ensures that values.ndim == 2 at this point
# --> 347 index, columns = _get_axes(
#     348     values.shape[0], values.shape[1], index=index, columns=columns
#     349 )
#     351 _check_values_indices_shape_match(values, index, columns)
#     353 if typ == "array":
#
# File c:\Users\ASUS\anaconda3\lib\site-packages\pandas\core\internals\construction.py:761, in _get_axes(N, K, index, columns)
#     759     columns = default_index(K)
#     760 else:
# --> 761     columns = ensure_index(columns)
#     762 return index, columns
#
# File c:\Users\ASUS\anaconda3\lib\site-packages\pandas\core\indexes\base.py:7043, in ensure_index(index_like, copy)
#    7041         return Index._with_infer(index_like, copy=copy, tupleize_cols=False)
#    7042 else:
# -> 7043     return Index._with_infer(index_like, copy=copy)
#
# File c:\Users\ASUS\anaconda3\lib\site-packages\pandas\core\indexes\base.py:680, in Index._with_infer(cls, *args, **kwargs)
#     678 with warnings.catch_warnings():
#     679     warnings.filterwarnings("ignore", ".*the Index constructor", FutureWarning)
# --> 680     result = cls(*args, **kwargs)
#     682 if result.dtype == _dtype_obj and not result._is_multi:
#     683     # error: Argument 1 to "maybe_convert_objects" has incompatible type
#     684     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected
#     685     # "ndarray[Any, Any]"
#     686     values = lib.maybe_convert_objects(result._values)  # type: ignore[arg-type]
#
# File c:\Users\ASUS\anaconda3\lib\site-packages\pandas\core\indexes\base.py:528, in Index.__new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     523         return MultiIndex.from_tuples(
#     524             data, names=name or kwargs.get("names")
#     525         )
#     526 # other iterable of some kind
# --> 528 subarr = com.asarray_tuplesafe(data, dtype=_dtype_obj)
#     529 if dtype is None:
#     530     # with e.g. a list [1, 2, 3] casting to numeric is _not_ deprecated
#     531     # error: Incompatible types in assignment (expression has type
#     532     # "Union[ExtensionArray, ndarray[Any, Any]]", variable has type
#     533     # "ndarray[Any, Any]")
#     534     subarr = _maybe_cast_data_without_dtype(  # type: ignore[assignment]
#     535         subarr, cast_numeric_deprecated=False
#     536     )
#
# File c:\Users\ASUS\anaconda3\lib\site-packages\pandas\core\common.py:232, in asarray_tuplesafe(values, dtype)
#     229 def asarray_tuplesafe(values, dtype: NpDtype | None = None) -> np.ndarray:
#     231     if not (isinstance(values, (list, tuple)) or hasattr(values, "__array__")):
# --> 232         values = list(values)
#     233     elif isinstance(values, ABCIndex):
#     234         # error: Incompatible return value type (got "Union[ExtensionArray, ndarray]",
#     235         # expected "ndarray")
#     236         return values._values  # type: ignore[return-value]
#
# TypeError: 'method' object is not iterable

# %%
X_train.shape
# Out:
# (135501, 9)

# %%
X_test.shape
# Out:
# (58072, 9)

# %%
"""linear regression
ridge regression
lasso regression
elastic net"""

# %%
## Model Training

from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
import numpy as np
def evaluate_model(true, predicted):
    mae = mean_absolute_error(true, predicted)
    mse = mean_squared_error(true, predicted)
    rmse = np.sqrt(mean_squared_error(true, predicted))
    r2_square = r2_score(true, predicted)
    return mae, rmse, r2_square

# %%
## Train multiple models

models={
    'LinearRegression':LinearRegression(),
    'Lasso':Lasso(),
    'Ridge':Ridge(),
    'Elasticnet':ElasticNet()
}

# %%
trained_model_list=[]
model_list=[]
r2_list=[]

# %%
list(models)

# %%
for i in range(len(list(models))):
    model=list(models.values())[i]
    print(model)

# %%
models.keys()

# %%
models.values()

# %%
for i in range(len(list(models))):
    model=list(models.values())[i]
    model.fit(X_train,y_train)

    #Make Predictions
    y_pred=model.predict(X_test)

    #this is a validation(test) score
    mae, rmse, r2_square=evaluate_model(y_test,y_pred)

    print(list(models.keys())[i])
    model_list.append(list(models.keys())[i])

    print('Model Training Performance')
    print("RMSE:",rmse)
    print("MAE:",mae)
    print("R2 score",r2_square*100)

    r2_list.append(r2_square)
    
    print('='*35)
    print('\n')

# %%
trained_model_list

# %%
model_list

# %%
r2_list
